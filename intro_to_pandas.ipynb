# %% [markdown]
# ## <font color="coral"> Intro to Pandas</font>
#
# #### <font color="coral"> In this notebook we'll be looking at Scipy's Pandas library for data analysis. This notebook will briefly cover:</font>
#
# - Reading in .csv or .xlsx with pandas
# - Inspecting, indexing, and performing summary statistics on data
# - Finding summary statistics, exploratory data analysis
# - Creating new columns and modifying data
# - Filtering out or dropping unwanted data
# - Combining multiple data tables
#
# #### <font color="coral"> Notebook usage</font>
#
# This notebook is intended to be worked through top-to-bottom, feel free to change what you'd like and experiment with any ideas you have. To advance in the notebook you can click on each cell and hit the "▶️" button, or pressing "Shift-Enter/Return". Try running the cell below!

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### <font color="coral"> Pandas Intution
#
# Pandas is a library for examining "spreadsheet" style data. This is the general data format that Microsoft Excel and Google Sheets works with.
#
# To replicate the grid-like structure of the data within a .csv file, Pandas provides a `DataFrame` class. This class can be thought of as a **nested list or numpy nd.Array** grid object that can also be used like a python **dictionary**.

# %%
# Example of nested-list behavior

# Nested list
grid = np.array([
    ["Name", "Age", "Grade"],
    ["Carlos", 13, 8],
    ["Sandra", 8, 3]
])

# Can access rows or columns of a grid using an index []:
print("First data row:", grid[1])
print("Name of student in first row:", grid[1, 0])
# Out:
# First data row: ['Carlos' '13' '8']
# Name of student in first row: Carlos

# %%
# Example of dictionary behavior
pokemon_2_type = {
    "Charmander" : "Fire", 
    "Squirtle" : "Water",
    "Bulbasaur" : "Grass"
}

# dictionary values can be accessed using a "key"
print("What is Charmander's type again?")
print(pokemon_2_type["Charmander"])
# Out:
# What is Charmander's type again?
# Fire

# %% [markdown]
# ##### When working with a pandas DataFrame:
# - Want to get a column? - dictionary-like syntax, `["column_name"]`
# - Want to get a row? - numpy or grid-like syntax, `[index_1, index_2]`

# %% [markdown]
# #### <font color="Coral"> Reading data into and viewing a DataFrame
#
# The primary methods of reading data from a .csv and .xlsx file are the `pd.read_csv()` and `pd.read_excel()`, respectively. In most cases, these functions have the data's `filepath` provided to them.
#
# <font color="coral"> Our practice data
#
# The data we will be using is volcano eruption and event data, provided publicly by [RforDataScience](https://github.com/rfordatascience/tidytuesday/blob/master/data/2020/2020-05-12/).
#
# Let's look at the data now!
#     1) Read in .csv data
#     2) Display data within DataFrame using `display()` and `head()`

# %%
# Store the data into a pandas dataframe
volc_tiny = pd.read_csv("volcano_data/filtered_volcano_tiny.csv")

# See how many rows and columns you're working with. Shape -> (rows, cols)
print("Df dims:", volc_tiny.shape)

# You can display the contents
display(volc_tiny.head())
# Out:
# Df dims: (30, 17)
#    volcano_number     volcano_name primary_volcano_type last_eruption_year  \
# 0          283001              Abu            Shield(s)              -6850
# 1          355096       Acamarachi        Stratovolcano            Unknown
# 2          342080       Acatenango    Stratovolcano(es)               1972
# 3          213004  Acigol-Nevsehir              Caldera              -2080
# 4          321040            Adams        Stratovolcano                950
#
#          country                          region  \
# 0          Japan         Japan, Taiwan, Marianas
# 1          Chile                   South America
# 2      Guatemala      México and Central America
# 3         Turkey  Mediterranean and Western Asia
# 4  United States          Canada and Western USA
#
#                                subregion  latitude  longitude  elevation  \
# 0                                 Honshu    34.500    131.600        641
# 1  Northern Chile, Bolivia and Argentina   -23.292    -67.618       6023
# 2                              Guatemala    14.501    -90.876       3976
# 3                                 Turkey    38.537     34.621       1683
# 4                       USA (Washington)    46.206   -121.490       3742
#
#                               tectonic_settings  evidence_category  \
# 0  Subduction zone / Continental crust (>25 km)     Eruption Dated
# 1  Subduction zone / Continental crust (>25 km)  Evidence Credible
# 2  Subduction zone / Continental crust (>25 km)  Eruption Observed
# 3       Intraplate / Continental crust (>25 km)     Eruption Dated
# 4  Subduction zone / Continental crust (>25 km)     Eruption Dated
#
#                    major_rock_1  population_within_5_km  \
# 0  Andesite / Basaltic Andesite                    3597
# 1                        Dacite                       0
# 2  Andesite / Basaltic Andesite                    4329
# 3                      Rhyolite                  127863
# 4  Andesite / Basaltic Andesite                       0
#
#    population_within_10_km  population_within_30_km  population_within_100_km
# 0                     9594                   117805                   4071152
# 1                        7                      294                      9092
# 2                    60730                  1042836                   7634778
# 3                   127863                   218469                   2253483
# 4                       70                     4019                    393303

# %%
# Important to look at columns and index
print(volc_tiny.columns)
print()

print(volc_tiny.index)
# Out:
# Index(['volcano_number', 'volcano_name', 'primary_volcano_type',
#        'last_eruption_year', 'country', 'region', 'subregion', 'latitude',
#        'longitude', 'elevation', 'tectonic_settings', 'evidence_category',
#        'major_rock_1', 'population_within_5_km', 'population_within_10_km',
#        'population_within_30_km', 'population_within_100_km'],
#       dtype='object')
#
# RangeIndex(start=0, stop=30, step=1)

# %%
# Let's look at an individual column
display(volc_tiny["volcano_name"]) # can also do volc_tiny.volcano_name

# And multiple columns at once
display(volc_tiny[["volcano_name", "country"]])
# Out:
# 0                  Abu
# 1           Acamarachi
# 2           Acatenango
# 3      Acigol-Nevsehir
# 4                Adams
# 5          Adatarayama
# 6                 Adwa
# 7               Afdera
# 8              Agrigan
# 9                 Agua
# 10         Agua de Pau
# 11            Aguilera
# 12               Agung
# 13                Ahyi
# 14                Aira
# 15       Akademia Nauk
# 16            Akagisan
# 17                Akan
# 18    Akita-Komagatake
# 19      Akita-Yakeyama
# 20         Akusekijima
# 21              Akutan
# 22               Alaid
# 23              Alayta
# 24              Alcedo
# 25            Ale Bagu
# 26                Alid
# 27               Aliso
# 28      Alligator Lake
# 29           Almolonga
# Name: volcano_name, dtype: object
#         volcano_name        country
# 0                Abu          Japan
# 1         Acamarachi          Chile
# 2         Acatenango      Guatemala
# 3    Acigol-Nevsehir         Turkey
# 4              Adams  United States
# 5        Adatarayama          Japan
# 6               Adwa       Ethiopia
# 7             Afdera       Ethiopia
# 8            Agrigan  United States
# 9               Agua      Guatemala
# 10       Agua de Pau       Portugal
# 11          Aguilera          Chile
# 12             Agung      Indonesia
# 13              Ahyi  United States
# 14              Aira          Japan
# 15     Akademia Nauk         Russia
# 16          Akagisan          Japan
# 17              Akan          Japan
# 18  Akita-Komagatake          Japan
# 19    Akita-Yakeyama          Japan
# 20       Akusekijima          Japan
# 21            Akutan  United States
# 22             Alaid         Russia
# 23            Alayta       Ethiopia
# 24            Alcedo        Ecuador
# 25          Ale Bagu       Ethiopia
# 26              Alid        Eritrea
# 27             Aliso        Ecuador
# 28    Alligator Lake         Canada
# 29         Almolonga      Guatemala

# %%
# Why does the first column printed look different from the second columns printed?
print(type(volc_tiny.volcano_name))
print(type(volc_tiny[["volcano_name", "country"]]))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
# And now an individual
display(volc_tiny.iloc[0])

# and multiple rows
display(volc_tiny.iloc[0:5])
# Out:
# volcano_number                                                    283001
# volcano_name                                                         Abu
# primary_volcano_type                                           Shield(s)
# last_eruption_year                                                 -6850
# country                                                            Japan
# region                                           Japan, Taiwan, Marianas
# subregion                                                         Honshu
# latitude                                                            34.5
# longitude                                                          131.6
# elevation                                                            641
# tectonic_settings           Subduction zone / Continental crust (>25 km)
# evidence_category                                         Eruption Dated
# major_rock_1                                Andesite / Basaltic Andesite
# population_within_5_km                                              3597
# population_within_10_km                                             9594
# population_within_30_km                                           117805
# population_within_100_km                                         4071152
# Name: 0, dtype: object
#    volcano_number     volcano_name primary_volcano_type last_eruption_year  \
# 0          283001              Abu            Shield(s)              -6850
# 1          355096       Acamarachi        Stratovolcano            Unknown
# 2          342080       Acatenango    Stratovolcano(es)               1972
# 3          213004  Acigol-Nevsehir              Caldera              -2080
# 4          321040            Adams        Stratovolcano                950
#
#          country                          region  \
# 0          Japan         Japan, Taiwan, Marianas
# 1          Chile                   South America
# 2      Guatemala      México and Central America
# 3         Turkey  Mediterranean and Western Asia
# 4  United States          Canada and Western USA
#
#                                subregion  latitude  longitude  elevation  \
# 0                                 Honshu    34.500    131.600        641
# 1  Northern Chile, Bolivia and Argentina   -23.292    -67.618       6023
# 2                              Guatemala    14.501    -90.876       3976
# 3                                 Turkey    38.537     34.621       1683
# 4                       USA (Washington)    46.206   -121.490       3742
#
#                               tectonic_settings  evidence_category  \
# 0  Subduction zone / Continental crust (>25 km)     Eruption Dated
# 1  Subduction zone / Continental crust (>25 km)  Evidence Credible
# 2  Subduction zone / Continental crust (>25 km)  Eruption Observed
# 3       Intraplate / Continental crust (>25 km)     Eruption Dated
# 4  Subduction zone / Continental crust (>25 km)     Eruption Dated
#
#                    major_rock_1  population_within_5_km  \
# 0  Andesite / Basaltic Andesite                    3597
# 1                        Dacite                       0
# 2  Andesite / Basaltic Andesite                    4329
# 3                      Rhyolite                  127863
# 4  Andesite / Basaltic Andesite                       0
#
#    population_within_10_km  population_within_30_km  population_within_100_km
# 0                     9594                   117805                   4071152
# 1                        7                      294                      9092
# 2                    60730                  1042836                   7634778
# 3                   127863                   218469                   2253483
# 4                       70                     4019                    393303

# %%
# only look at two columns for the first 5 rows?
display(volc_tiny.loc[0:5, ["volcano_name", "country"]])
# Out:
#       volcano_name        country
# 0              Abu          Japan
# 1       Acamarachi          Chile
# 2       Acatenango      Guatemala
# 3  Acigol-Nevsehir         Turkey
# 4            Adams  United States
# 5      Adatarayama          Japan

# %% [markdown]
# #### <font color="coral"> Analyzing data within your DataFrame</font>
#
# Pandas Series support most simple statistics operations:
# - `mean(), mode(), min(), max(), std(), sum()`
#
# They also provide some useful data summaries:
# - `.value_counts(), nunique()`

# %%
# Let's find a column and do some stats!

# Stats of population 10km of a volcano
print(volc_tiny.population_within_10_km.mean())
print(volc_tiny.population_within_10_km.max())
print(volc_tiny.population_within_10_km.min())
print(volc_tiny.population_within_10_km.std())
print(volc_tiny.population_within_10_km.sum())
# Out:
# 27815.133333333335
# 287487
# 0
# 62122.50704898004
# 834454

# %%
# What types of volcanoes are present in the data?
volc_tiny.primary_volcano_type.value_counts()
# Out:
# Stratovolcano        17
# Stratovolcano(es)     5
# Caldera               3
# Shield                2
# Submarine             1
# Volcanic field        1
# Shield(s)             1
# Name: primary_volcano_type, dtype: int64

# %%
# How many countries are represented in the data?
volc_tiny.country.nunique()
# Out:
# 12

# %% [markdown]
# #### <font color="coral"> Adding and modifying data </font>
#
# It's possible to add new columns, rows, and to alter data already within a pandas dataframe.
#
# 1. Add a new column to DataFrame `df` with: `df["new_column_name"] = (some value, Series, List, np.Array)`
# 2. Add a new row with: `df.append(new_row, inplace=True)`
# 3. Alter data (very conservatively) with `df.iloc[index_1, index_2] = new_val`
#
# You can also change a column's name with `.rename()`

# %%
# Let's add a new column to our dataset signifying where the data came from 
display(volc_tiny.head())
volc_tiny["dataset"] = "Tiny"
display(volc_tiny.head())
# Out:
#    volcano_number     volcano_name primary_volcano_type last_eruption_year  \
# 0          283001              Abu            Shield(s)              -6850
# 1          355096       Acamarachi        Stratovolcano            Unknown
# 2          342080       Acatenango    Stratovolcano(es)               1972
# 3          213004  Acigol-Nevsehir              Caldera              -2080
# 4          321040            Adams        Stratovolcano                950
#
#          country                          region  \
# 0          Japan         Japan, Taiwan, Marianas
# 1          Chile                   South America
# 2      Guatemala      México and Central America
# 3         Turkey  Mediterranean and Western Asia
# 4  United States          Canada and Western USA
#
#                                subregion  latitude  longitude  elevation  \
# 0                                 Honshu    34.500    131.600        641
# 1  Northern Chile, Bolivia and Argentina   -23.292    -67.618       6023
# 2                              Guatemala    14.501    -90.876       3976
# 3                                 Turkey    38.537     34.621       1683
# 4                       USA (Washington)    46.206   -121.490       3742
#
#                               tectonic_settings  evidence_category  \
# 0  Subduction zone / Continental crust (>25 km)     Eruption Dated
# 1  Subduction zone / Continental crust (>25 km)  Evidence Credible
# 2  Subduction zone / Continental crust (>25 km)  Eruption Observed
# 3       Intraplate / Continental crust (>25 km)     Eruption Dated
# 4  Subduction zone / Continental crust (>25 km)     Eruption Dated
#
#                    major_rock_1  population_within_5_km  \
# 0  Andesite / Basaltic Andesite                    3597
# 1                        Dacite                       0
# 2  Andesite / Basaltic Andesite                    4329
# 3                      Rhyolite                  127863
# 4  Andesite / Basaltic Andesite                       0
#
#    population_within_10_km  population_within_30_km  population_within_100_km
# 0                     9594                   117805                   4071152
# 1                        7                      294                      9092
# 2                    60730                  1042836                   7634778
# 3                   127863                   218469                   2253483
# 4                       70                     4019                    393303
#    volcano_number     volcano_name primary_volcano_type last_eruption_year  \
# 0          283001              Abu            Shield(s)              -6850
# 1          355096       Acamarachi        Stratovolcano            Unknown
# 2          342080       Acatenango    Stratovolcano(es)               1972
# 3          213004  Acigol-Nevsehir              Caldera              -2080
# 4          321040            Adams        Stratovolcano                950
#
#          country                          region  \
# 0          Japan         Japan, Taiwan, Marianas
# 1          Chile                   South America
# 2      Guatemala      México and Central America
# 3         Turkey  Mediterranean and Western Asia
# 4  United States          Canada and Western USA
#
#                                subregion  latitude  longitude  elevation  \
# 0                                 Honshu    34.500    131.600        641
# 1  Northern Chile, Bolivia and Argentina   -23.292    -67.618       6023
# 2                              Guatemala    14.501    -90.876       3976
# 3                                 Turkey    38.537     34.621       1683
# 4                       USA (Washington)    46.206   -121.490       3742
#
#                               tectonic_settings  evidence_category  \
# 0  Subduction zone / Continental crust (>25 km)     Eruption Dated
# 1  Subduction zone / Continental crust (>25 km)  Evidence Credible
# 2  Subduction zone / Continental crust (>25 km)  Eruption Observed
# 3       Intraplate / Continental crust (>25 km)     Eruption Dated
# 4  Subduction zone / Continental crust (>25 km)     Eruption Dated
#
#                    major_rock_1  population_within_5_km  \
# 0  Andesite / Basaltic Andesite                    3597
# 1                        Dacite                       0
# 2  Andesite / Basaltic Andesite                    4329
# 3                      Rhyolite                  127863
# 4  Andesite / Basaltic Andesite                       0
#
#    population_within_10_km  population_within_30_km  population_within_100_km  \
# 0                     9594                   117805                   4071152
# 1                        7                      294                      9092
# 2                    60730                  1042836                   7634778
# 3                   127863                   218469                   2253483
# 4                       70                     4019                    393303
#
#   dataset
# 0    Tiny
# 1    Tiny
# 2    Tiny
# 3    Tiny
# 4    Tiny

# %%
# Maybe we want to double up or preserve a row:
row_0 = volc_tiny.iloc[0]
print(volc_tiny.shape)
volc_tiny = volc_tiny.append(row_0)
print(volc_tiny.shape)
# Out:
# (30, 18)
# (31, 18)

# %%
# Manually "correct" an incorrect cell
display(volc_tiny.iloc[2])
volc_tiny.iloc[2, -5] = 3000
display(volc_tiny.iloc[2])
# Out:
# volcano_number                                                    342080
# volcano_name                                                  Acatenango
# primary_volcano_type                                   Stratovolcano(es)
# last_eruption_year                                                  1972
# country                                                        Guatemala
# region                                        México and Central America
# subregion                                                      Guatemala
# latitude                                                          14.501
# longitude                                                        -90.876
# elevation                                                           3976
# tectonic_settings           Subduction zone / Continental crust (>25 km)
# evidence_category                                      Eruption Observed
# major_rock_1                                Andesite / Basaltic Andesite
# population_within_5_km                                              4329
# population_within_10_km                                            60730
# population_within_30_km                                          1042836
# population_within_100_km                                         7634778
# dataset                                                             Tiny
# Name: 2, dtype: object
# volcano_number                                                    342080
# volcano_name                                                  Acatenango
# primary_volcano_type                                   Stratovolcano(es)
# last_eruption_year                                                  1972
# country                                                        Guatemala
# region                                        México and Central America
# subregion                                                      Guatemala
# latitude                                                          14.501
# longitude                                                        -90.876
# elevation                                                           3976
# tectonic_settings           Subduction zone / Continental crust (>25 km)
# evidence_category                                      Eruption Observed
# major_rock_1                                Andesite / Basaltic Andesite
# population_within_5_km                                              3000
# population_within_10_km                                            60730
# population_within_30_km                                          1042836
# population_within_100_km                                         7634778
# dataset                                                             Tiny
# Name: 2, dtype: object

# %% [markdown]
# #### <font color="coral"> Contrived Example, Matching Columns </font>
#
# Here's the scenario, you are trying to combine your current volcano dataset with a second  dataset. However, in the "evidence_category" column, this second dataset uses abbreviations instead of writing everything out:
# - your dataset - new dataset
# - Evidence Credible - EC
# - Eruption Observed - EO
# - Eruption Dated - ED
# - Eruption Uncertain - EU

# %%
# Dedicated cell to show off pd.str magic
volc_tiny.evidence_category.str.split()
# Out:
# 0         [Eruption, Dated]
# 1      [Evidence, Credible]
# 2      [Eruption, Observed]
# 3         [Eruption, Dated]
# 4         [Eruption, Dated]
# 5      [Eruption, Observed]
# 6      [Evidence, Credible]
# 7     [Evidence, Uncertain]
# 8      [Eruption, Observed]
# 9      [Evidence, Credible]
# 10     [Eruption, Observed]
# 11        [Eruption, Dated]
# 12     [Eruption, Observed]
# 13        [Eruption, Dated]
# 14     [Eruption, Observed]
# 15     [Eruption, Observed]
# 16    [Evidence, Uncertain]
# 17     [Eruption, Observed]
# 18     [Eruption, Observed]
# 19     [Eruption, Observed]
# 20    [Evidence, Uncertain]
# 21     [Eruption, Observed]
# 22     [Eruption, Observed]
# 23     [Eruption, Observed]
# 24     [Eruption, Observed]
# 25     [Evidence, Credible]
# 26     [Evidence, Credible]
# 27        [Eruption, Dated]
# 28     [Evidence, Credible]
# 29     [Eruption, Observed]
# 0         [Eruption, Dated]
# Name: evidence_category, dtype: object

# %%
volc_tiny["abbrev_evidence"] = "E" + volc_tiny.evidence_category.str.split().str[1].str[0]
volc_tiny["abbrev_evidence"]
# Out:
# 0     ED
# 1     EC
# 2     EO
# 3     ED
# 4     ED
# 5     EO
# 6     EC
# 7     EU
# 8     EO
# 9     EC
# 10    EO
# 11    ED
# 12    EO
# 13    ED
# 14    EO
# 15    EO
# 16    EU
# 17    EO
# 18    EO
# 19    EO
# 20    EU
# 21    EO
# 22    EO
# 23    EO
# 24    EO
# 25    EC
# 26    EC
# 27    ED
# 28    EC
# 29    EO
# 0     ED
# Name: abbrev_evidence, dtype: object

# %% [markdown]
# #### <font color="coral"> Filtering unwanted data </font>
#
# Now we want to do some analysis without all of our data. Perhaps some of our data is poor quality or is irrelevant to the question we'd like to ask.
#
# The syntax for filtering data in pandas can be verbose and gets much easier with experience in python/numpy idioms. The steps are:
# 1. Make a "boolean" Series or DataFrame with `True` or `False` values
# 2. Use the boolean Series or DataFrame to filter, all the `True` values are kept
#
# You can create a boolean Series by using regular comparison operators, `< > <= >= == !=`
#
# If you want to keep or filter multiple values, you can use `Series.isin()`
#
# Finally, you can negate a boolean Series or DataFrame with a `~` symbol in front.

# %%
# Only keep volcanoes with 100,000 or more people with 10km

# Create Boolean
display(volc_tiny.population_within_10_km.iloc[0:5])
volc_tiny.population_within_10_km.iloc[0:5] > 100000
# Out:
# 0      9594
# 1         7
# 2     60730
# 3    127863
# 4        70
# Name: population_within_10_km, dtype: int64
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# Name: population_within_10_km, dtype: bool

# %%
volc_tiny[volc_tiny.population_within_10_km > 1e5]
# Out:
#     volcano_number     volcano_name primary_volcano_type last_eruption_year  \
# 3           213004  Acigol-Nevsehir              Caldera              -2080
# 9           342100             Agua        Stratovolcano            Unknown
# 14          282080             Aira              Caldera               2020
# 29          342040        Almolonga        Stratovolcano               1818
#
#       country                          region                  subregion  \
# 3      Turkey  Mediterranean and Western Asia                     Turkey
# 9   Guatemala      México and Central America                  Guatemala
# 14      Japan         Japan, Taiwan, Marianas  Ryukyu Islands and Kyushu
# 29  Guatemala      México and Central America                  Guatemala
#
#     latitude  longitude  elevation  \
# 3     38.537     34.621       1683
# 9     14.465    -90.743       3760
# 14    31.593    130.657       1117
# 29    14.797    -91.519       3173
#
#                                tectonic_settings  evidence_category  \
# 3        Intraplate / Continental crust (>25 km)     Eruption Dated
# 9   Subduction zone / Continental crust (>25 km)  Evidence Credible
# 14  Subduction zone / Continental crust (>25 km)  Eruption Observed
# 29  Subduction zone / Continental crust (>25 km)  Eruption Observed
#
#                     major_rock_1  population_within_5_km  \
# 3                       Rhyolite                  127863
# 9   Andesite / Basaltic Andesite                    9890
# 14  Andesite / Basaltic Andesite                    4918
# 29                        Dacite                   91323
#
#     population_within_10_km  population_within_30_km  \
# 3                    127863                   218469
# 9                    114404                  2530449
# 14                   113874                   905254
# 29                   287487                  1126942
#
#     population_within_100_km dataset abbrev_evidence
# 3                    2253483    Tiny              ED
# 9                    7441660    Tiny              EC
# 14                   2610033    Tiny              EO
# 29                   6828403    Tiny              EO

# %%
# and the opposite, volcanoes with < 100000 population w/in 10km?
volc_tiny[~(volc_tiny.population_within_10_km > 1e5)]
# Out:
#     volcano_number      volcano_name primary_volcano_type last_eruption_year  \
# 0           283001               Abu            Shield(s)              -6850
# 1           355096        Acamarachi        Stratovolcano            Unknown
# 2           342080        Acatenango    Stratovolcano(es)               1972
# 4           321040             Adams        Stratovolcano                950
# 5           283170       Adatarayama    Stratovolcano(es)               1996
# 6           221170              Adwa        Stratovolcano            Unknown
# 7           221110            Afdera        Stratovolcano            Unknown
# 8           284160           Agrigan        Stratovolcano               1917
# 10          382090       Agua de Pau        Stratovolcano               1564
# 11          358062          Aguilera        Stratovolcano              -1250
# 12          264020             Agung        Stratovolcano               2019
# 13          284141              Ahyi            Submarine               2014
# 15          300125     Akademia Nauk    Stratovolcano(es)               1996
# 16          283130          Akagisan        Stratovolcano            Unknown
# 17          285070              Akan              Caldera               2008
# 18          283230  Akita-Komagatake    Stratovolcano(es)               1971
# 19          283260    Akita-Yakeyama        Stratovolcano               1997
# 20          282022       Akusekijima    Stratovolcano(es)            Unknown
# 21          311320            Akutan        Stratovolcano               1992
# 22          290390             Alaid        Stratovolcano               2018
# 23          221112            Alayta               Shield               1915
# 24          353040            Alcedo               Shield               1993
# 25          221090          Ale Bagu        Stratovolcano            Unknown
# 26          221040              Alid        Stratovolcano            Unknown
# 27          352031             Aliso        Stratovolcano              -2450
# 28          320020    Alligator Lake       Volcanic field            Unknown
# 0           283001               Abu            Shield(s)              -6850
#
#           country                       region  \
# 0           Japan      Japan, Taiwan, Marianas
# 1           Chile                South America
# 2       Guatemala   México and Central America
# 4   United States       Canada and Western USA
# 5           Japan      Japan, Taiwan, Marianas
# 6        Ethiopia           Africa and Red Sea
# 7        Ethiopia           Africa and Red Sea
# 8   United States      Japan, Taiwan, Marianas
# 10       Portugal               Atlantic Ocean
# 11          Chile                South America
# 12      Indonesia                    Indonesia
# 13  United States      Japan, Taiwan, Marianas
# 15         Russia  Kamchatka and Mainland Asia
# 16          Japan      Japan, Taiwan, Marianas
# 17          Japan      Japan, Taiwan, Marianas
# 18          Japan      Japan, Taiwan, Marianas
# 19          Japan      Japan, Taiwan, Marianas
# 20          Japan      Japan, Taiwan, Marianas
# 21  United States                       Alaska
# 22         Russia                Kuril Islands
# 23       Ethiopia           Africa and Red Sea
# 24        Ecuador                South America
# 25       Ethiopia           Africa and Red Sea
# 26        Eritrea           Africa and Red Sea
# 27        Ecuador                South America
# 28         Canada       Canada and Western USA
# 0           Japan      Japan, Taiwan, Marianas
#
#                                 subregion  latitude  longitude  elevation  \
# 0                                  Honshu    34.500    131.600        641
# 1   Northern Chile, Bolivia and Argentina   -23.292    -67.618       6023
# 2                               Guatemala    14.501    -90.876       3976
# 4                        USA (Washington)    46.206   -121.490       3742
# 5                                  Honshu    37.647    140.281       1728
# 6       Africa (northeastern) and Red Sea    10.070     40.840       1733
# 7       Africa (northeastern) and Red Sea    13.088     40.853       1250
# 8       Izu, Volcano, and Mariana Islands    18.770    145.670        965
# 10                                 Azores    37.770    -25.470        947
# 11           Southern Chile and Argentina   -50.330    -73.750       2546
# 12                   Lesser Sunda Islands    -8.343    115.508       2997
# 13      Izu, Volcano, and Mariana Islands    20.420    145.030        -75
# 15                    Kamchatka Peninsula    53.980    159.450       1180
# 16                                 Honshu    36.560    139.193       1828
# 17                               Hokkaido    43.384    144.013       1499
# 18                                 Honshu    39.761    140.799       1637
# 19                                 Honshu    39.964    140.757       1366
# 20              Ryukyu Islands and Kyushu    29.465    129.594        555
# 21                       Aleutian Islands    54.134   -165.986       1303
# 22                          Kuril Islands    50.861    155.565       2285
# 23      Africa (northeastern) and Red Sea    12.888     40.573       1496
# 24                      Galapagos Islands    -0.430    -91.120       1130
# 25      Africa (northeastern) and Red Sea    13.512     40.631        988
# 26      Africa (northeastern) and Red Sea    14.880     39.920        904
# 27                                Ecuador    -0.530    -78.000       4267
# 28                                 Canada    60.420   -135.420       2217
# 0                                  Honshu    34.500    131.600        641
#
#                                   tectonic_settings   evidence_category  \
# 0      Subduction zone / Continental crust (>25 km)      Eruption Dated
# 1      Subduction zone / Continental crust (>25 km)   Evidence Credible
# 2      Subduction zone / Continental crust (>25 km)   Eruption Observed
# 4      Subduction zone / Continental crust (>25 km)      Eruption Dated
# 5      Subduction zone / Continental crust (>25 km)   Eruption Observed
# 6         Rift zone / Intermediate crust (15-25 km)   Evidence Credible
# 7         Rift zone / Intermediate crust (15-25 km)  Evidence Uncertain
# 8       Subduction zone / Crustal thickness unknown   Eruption Observed
# 10              Rift zone / Oceanic crust (< 15 km)   Eruption Observed
# 11     Subduction zone / Continental crust (>25 km)      Eruption Dated
# 12     Subduction zone / Continental crust (>25 km)   Eruption Observed
# 13      Subduction zone / Crustal thickness unknown      Eruption Dated
# 15     Subduction zone / Continental crust (>25 km)   Eruption Observed
# 16     Subduction zone / Continental crust (>25 km)  Evidence Uncertain
# 17     Subduction zone / Continental crust (>25 km)   Eruption Observed
# 18     Subduction zone / Continental crust (>25 km)   Eruption Observed
# 19     Subduction zone / Continental crust (>25 km)   Eruption Observed
# 20        Subduction zone / Oceanic crust (< 15 km)  Evidence Uncertain
# 21  Subduction zone / Intermediate crust (15-25 km)   Eruption Observed
# 22     Subduction zone / Continental crust (>25 km)   Eruption Observed
# 23        Rift zone / Intermediate crust (15-25 km)   Eruption Observed
# 24              Rift zone / Oceanic crust (< 15 km)   Eruption Observed
# 25        Rift zone / Intermediate crust (15-25 km)   Evidence Credible
# 26        Rift zone / Intermediate crust (15-25 km)   Evidence Credible
# 27     Subduction zone / Continental crust (>25 km)      Eruption Dated
# 28          Intraplate / Continental crust (>25 km)   Evidence Credible
# 0      Subduction zone / Continental crust (>25 km)      Eruption Dated
#
#                     major_rock_1  population_within_5_km  \
# 0   Andesite / Basaltic Andesite                    3597
# 1                         Dacite                       0
# 2   Andesite / Basaltic Andesite                    3000
# 4   Andesite / Basaltic Andesite                       0
# 5   Andesite / Basaltic Andesite                     428
# 6                       Rhyolite                     101
# 7                       Rhyolite                      51
# 8          Basalt / Picro-Basalt                       0
# 10       Trachyte / Trachydacite                     406
# 11                        Dacite                       0
# 12  Andesite / Basaltic Andesite                    5657
# 13  Andesite / Basaltic Andesite                       0
# 15  Andesite / Basaltic Andesite                       3
# 16  Andesite / Basaltic Andesite                     961
# 17  Andesite / Basaltic Andesite                    2062
# 18         Basalt / Picro-Basalt                     376
# 19  Andesite / Basaltic Andesite                     127
# 20  Andesite / Basaltic Andesite                      52
# 21         Basalt / Picro-Basalt                       0
# 22         Basalt / Picro-Basalt                       0
# 23         Basalt / Picro-Basalt                     156
# 24         Basalt / Picro-Basalt                     290
# 25         Basalt / Picro-Basalt                       2
# 26                      Rhyolite                     517
# 27  Andesite / Basaltic Andesite                       0
# 28         Basalt / Picro-Basalt                       0
# 0   Andesite / Basaltic Andesite                    3597
#
#     population_within_10_km  population_within_30_km  \
# 0                      9594                   117805
# 1                         7                      294
# 2                     60730                  1042836
# 4                        70                     4019
# 5                      3936                   717078
# 6                       485                    18645
# 7                      6042                     8611
# 8                         0                        0
# 10                    17272                   113131
# 11                        0                      103
# 12                    76781                   968381
# 13                        0                        0
# 15                        3                      615
# 16                     4538                  1116366
# 17                     2062                     9756
# 18                     3864                   216708
# 19                      721                    55493
# 20                       52                      199
# 21                       24                      233
# 22                       64                       64
# 23                      925                    13459
# 24                      290                      388
# 25                      919                     8424
# 26                     2447                    25942
# 27                        0                        0
# 28                        0                       47
# 0                      9594                   117805
#
#     population_within_100_km dataset abbrev_evidence
# 0                    4071152    Tiny              ED
# 1                       9092    Tiny              EC
# 2                    7634778    Tiny              EO
# 4                     393303    Tiny              ED
# 5                    5024654    Tiny              EO
# 6                    1242922    Tiny              EC
# 7                     161009    Tiny              EU
# 8                          0    Tiny              EO
# 10                    119653    Tiny              EO
# 11                      5698    Tiny              ED
# 12                   4550176    Tiny              EO
# 13                         0    Tiny              ED
# 15                     12484    Tiny              EO
# 16                  16718375    Tiny              EU
# 17                    929538    Tiny              EO
# 18                   2521611    Tiny              EO
# 19                   3122037    Tiny              EO
# 20                       749    Tiny              EU
# 21                      4361    Tiny              EO
# 22                      2887    Tiny              EO
# 23                    330411    Tiny              EO
# 24                     10756    Tiny              EO
# 25                    278270    Tiny              EC
# 26                   1216179    Tiny              EC
# 27                         0    Tiny              ED
# 28                     20636    Tiny              EC
# 0                    4071152    Tiny              ED

# %%
# Only keep volcanoes for which the eruption was observed
volc_tiny[volc_tiny.evidence_category == "Eruption Observed"]
# Out:
#     volcano_number      volcano_name primary_volcano_type last_eruption_year  \
# 2           342080        Acatenango    Stratovolcano(es)               1972
# 5           283170       Adatarayama    Stratovolcano(es)               1996
# 8           284160           Agrigan        Stratovolcano               1917
# 10          382090       Agua de Pau        Stratovolcano               1564
# 12          264020             Agung        Stratovolcano               2019
# 14          282080              Aira              Caldera               2020
# 15          300125     Akademia Nauk    Stratovolcano(es)               1996
# 17          285070              Akan              Caldera               2008
# 18          283230  Akita-Komagatake    Stratovolcano(es)               1971
# 19          283260    Akita-Yakeyama        Stratovolcano               1997
# 21          311320            Akutan        Stratovolcano               1992
# 22          290390             Alaid        Stratovolcano               2018
# 23          221112            Alayta               Shield               1915
# 24          353040            Alcedo               Shield               1993
# 29          342040         Almolonga        Stratovolcano               1818
#
#           country                       region  \
# 2       Guatemala   México and Central America
# 5           Japan      Japan, Taiwan, Marianas
# 8   United States      Japan, Taiwan, Marianas
# 10       Portugal               Atlantic Ocean
# 12      Indonesia                    Indonesia
# 14          Japan      Japan, Taiwan, Marianas
# 15         Russia  Kamchatka and Mainland Asia
# 17          Japan      Japan, Taiwan, Marianas
# 18          Japan      Japan, Taiwan, Marianas
# 19          Japan      Japan, Taiwan, Marianas
# 21  United States                       Alaska
# 22         Russia                Kuril Islands
# 23       Ethiopia           Africa and Red Sea
# 24        Ecuador                South America
# 29      Guatemala   México and Central America
#
#                             subregion  latitude  longitude  elevation  \
# 2                           Guatemala    14.501    -90.876       3976
# 5                              Honshu    37.647    140.281       1728
# 8   Izu, Volcano, and Mariana Islands    18.770    145.670        965
# 10                             Azores    37.770    -25.470        947
# 12               Lesser Sunda Islands    -8.343    115.508       2997
# 14          Ryukyu Islands and Kyushu    31.593    130.657       1117
# 15                Kamchatka Peninsula    53.980    159.450       1180
# 17                           Hokkaido    43.384    144.013       1499
# 18                             Honshu    39.761    140.799       1637
# 19                             Honshu    39.964    140.757       1366
# 21                   Aleutian Islands    54.134   -165.986       1303
# 22                      Kuril Islands    50.861    155.565       2285
# 23  Africa (northeastern) and Red Sea    12.888     40.573       1496
# 24                  Galapagos Islands    -0.430    -91.120       1130
# 29                          Guatemala    14.797    -91.519       3173
#
#                                   tectonic_settings  evidence_category  \
# 2      Subduction zone / Continental crust (>25 km)  Eruption Observed
# 5      Subduction zone / Continental crust (>25 km)  Eruption Observed
# 8       Subduction zone / Crustal thickness unknown  Eruption Observed
# 10              Rift zone / Oceanic crust (< 15 km)  Eruption Observed
# 12     Subduction zone / Continental crust (>25 km)  Eruption Observed
# 14     Subduction zone / Continental crust (>25 km)  Eruption Observed
# 15     Subduction zone / Continental crust (>25 km)  Eruption Observed
# 17     Subduction zone / Continental crust (>25 km)  Eruption Observed
# 18     Subduction zone / Continental crust (>25 km)  Eruption Observed
# 19     Subduction zone / Continental crust (>25 km)  Eruption Observed
# 21  Subduction zone / Intermediate crust (15-25 km)  Eruption Observed
# 22     Subduction zone / Continental crust (>25 km)  Eruption Observed
# 23        Rift zone / Intermediate crust (15-25 km)  Eruption Observed
# 24              Rift zone / Oceanic crust (< 15 km)  Eruption Observed
# 29     Subduction zone / Continental crust (>25 km)  Eruption Observed
#
#                     major_rock_1  population_within_5_km  \
# 2   Andesite / Basaltic Andesite                    3000
# 5   Andesite / Basaltic Andesite                     428
# 8          Basalt / Picro-Basalt                       0
# 10       Trachyte / Trachydacite                     406
# 12  Andesite / Basaltic Andesite                    5657
# 14  Andesite / Basaltic Andesite                    4918
# 15  Andesite / Basaltic Andesite                       3
# 17  Andesite / Basaltic Andesite                    2062
# 18         Basalt / Picro-Basalt                     376
# 19  Andesite / Basaltic Andesite                     127
# 21         Basalt / Picro-Basalt                       0
# 22         Basalt / Picro-Basalt                       0
# 23         Basalt / Picro-Basalt                     156
# 24         Basalt / Picro-Basalt                     290
# 29                        Dacite                   91323
#
#     population_within_10_km  population_within_30_km  \
# 2                     60730                  1042836
# 5                      3936                   717078
# 8                         0                        0
# 10                    17272                   113131
# 12                    76781                   968381
# 14                   113874                   905254
# 15                        3                      615
# 17                     2062                     9756
# 18                     3864                   216708
# 19                      721                    55493
# 21                       24                      233
# 22                       64                       64
# 23                      925                    13459
# 24                      290                      388
# 29                   287487                  1126942
#
#     population_within_100_km dataset abbrev_evidence
# 2                    7634778    Tiny              EO
# 5                    5024654    Tiny              EO
# 8                          0    Tiny              EO
# 10                    119653    Tiny              EO
# 12                   4550176    Tiny              EO
# 14                   2610033    Tiny              EO
# 15                     12484    Tiny              EO
# 17                    929538    Tiny              EO
# 18                   2521611    Tiny              EO
# 19                   3122037    Tiny              EO
# 21                      4361    Tiny              EO
# 22                      2887    Tiny              EO
# 23                    330411    Tiny              EO
# 24                     10756    Tiny              EO
# 29                   6828403    Tiny              EO

# %%
# Only keep volcanoes for which eruption observed or eruption dated
volc_tiny[volc_tiny.evidence_category.isin(["Eruption Observed", "Eruption Dated"])]
# Out:
#     volcano_number      volcano_name primary_volcano_type last_eruption_year  \
# 0           283001               Abu            Shield(s)              -6850
# 2           342080        Acatenango    Stratovolcano(es)               1972
# 3           213004   Acigol-Nevsehir              Caldera              -2080
# 4           321040             Adams        Stratovolcano                950
# 5           283170       Adatarayama    Stratovolcano(es)               1996
# 8           284160           Agrigan        Stratovolcano               1917
# 10          382090       Agua de Pau        Stratovolcano               1564
# 11          358062          Aguilera        Stratovolcano              -1250
# 12          264020             Agung        Stratovolcano               2019
# 13          284141              Ahyi            Submarine               2014
# 14          282080              Aira              Caldera               2020
# 15          300125     Akademia Nauk    Stratovolcano(es)               1996
# 17          285070              Akan              Caldera               2008
# 18          283230  Akita-Komagatake    Stratovolcano(es)               1971
# 19          283260    Akita-Yakeyama        Stratovolcano               1997
# 21          311320            Akutan        Stratovolcano               1992
# 22          290390             Alaid        Stratovolcano               2018
# 23          221112            Alayta               Shield               1915
# 24          353040            Alcedo               Shield               1993
# 27          352031             Aliso        Stratovolcano              -2450
# 29          342040         Almolonga        Stratovolcano               1818
# 0           283001               Abu            Shield(s)              -6850
#
#           country                          region  \
# 0           Japan         Japan, Taiwan, Marianas
# 2       Guatemala      México and Central America
# 3          Turkey  Mediterranean and Western Asia
# 4   United States          Canada and Western USA
# 5           Japan         Japan, Taiwan, Marianas
# 8   United States         Japan, Taiwan, Marianas
# 10       Portugal                  Atlantic Ocean
# 11          Chile                   South America
# 12      Indonesia                       Indonesia
# 13  United States         Japan, Taiwan, Marianas
# 14          Japan         Japan, Taiwan, Marianas
# 15         Russia     Kamchatka and Mainland Asia
# 17          Japan         Japan, Taiwan, Marianas
# 18          Japan         Japan, Taiwan, Marianas
# 19          Japan         Japan, Taiwan, Marianas
# 21  United States                          Alaska
# 22         Russia                   Kuril Islands
# 23       Ethiopia              Africa and Red Sea
# 24        Ecuador                   South America
# 27        Ecuador                   South America
# 29      Guatemala      México and Central America
# 0           Japan         Japan, Taiwan, Marianas
#
#                             subregion  latitude  longitude  elevation  \
# 0                              Honshu    34.500    131.600        641
# 2                           Guatemala    14.501    -90.876       3976
# 3                              Turkey    38.537     34.621       1683
# 4                    USA (Washington)    46.206   -121.490       3742
# 5                              Honshu    37.647    140.281       1728
# 8   Izu, Volcano, and Mariana Islands    18.770    145.670        965
# 10                             Azores    37.770    -25.470        947
# 11       Southern Chile and Argentina   -50.330    -73.750       2546
# 12               Lesser Sunda Islands    -8.343    115.508       2997
# 13  Izu, Volcano, and Mariana Islands    20.420    145.030        -75
# 14          Ryukyu Islands and Kyushu    31.593    130.657       1117
# 15                Kamchatka Peninsula    53.980    159.450       1180
# 17                           Hokkaido    43.384    144.013       1499
# 18                             Honshu    39.761    140.799       1637
# 19                             Honshu    39.964    140.757       1366
# 21                   Aleutian Islands    54.134   -165.986       1303
# 22                      Kuril Islands    50.861    155.565       2285
# 23  Africa (northeastern) and Red Sea    12.888     40.573       1496
# 24                  Galapagos Islands    -0.430    -91.120       1130
# 27                            Ecuador    -0.530    -78.000       4267
# 29                          Guatemala    14.797    -91.519       3173
# 0                              Honshu    34.500    131.600        641
#
#                                   tectonic_settings  evidence_category  \
# 0      Subduction zone / Continental crust (>25 km)     Eruption Dated
# 2      Subduction zone / Continental crust (>25 km)  Eruption Observed
# 3           Intraplate / Continental crust (>25 km)     Eruption Dated
# 4      Subduction zone / Continental crust (>25 km)     Eruption Dated
# 5      Subduction zone / Continental crust (>25 km)  Eruption Observed
# 8       Subduction zone / Crustal thickness unknown  Eruption Observed
# 10              Rift zone / Oceanic crust (< 15 km)  Eruption Observed
# 11     Subduction zone / Continental crust (>25 km)     Eruption Dated
# 12     Subduction zone / Continental crust (>25 km)  Eruption Observed
# 13      Subduction zone / Crustal thickness unknown     Eruption Dated
# 14     Subduction zone / Continental crust (>25 km)  Eruption Observed
# 15     Subduction zone / Continental crust (>25 km)  Eruption Observed
# 17     Subduction zone / Continental crust (>25 km)  Eruption Observed
# 18     Subduction zone / Continental crust (>25 km)  Eruption Observed
# 19     Subduction zone / Continental crust (>25 km)  Eruption Observed
# 21  Subduction zone / Intermediate crust (15-25 km)  Eruption Observed
# 22     Subduction zone / Continental crust (>25 km)  Eruption Observed
# 23        Rift zone / Intermediate crust (15-25 km)  Eruption Observed
# 24              Rift zone / Oceanic crust (< 15 km)  Eruption Observed
# 27     Subduction zone / Continental crust (>25 km)     Eruption Dated
# 29     Subduction zone / Continental crust (>25 km)  Eruption Observed
# 0      Subduction zone / Continental crust (>25 km)     Eruption Dated
#
#                     major_rock_1  population_within_5_km  \
# 0   Andesite / Basaltic Andesite                    3597
# 2   Andesite / Basaltic Andesite                    3000
# 3                       Rhyolite                  127863
# 4   Andesite / Basaltic Andesite                       0
# 5   Andesite / Basaltic Andesite                     428
# 8          Basalt / Picro-Basalt                       0
# 10       Trachyte / Trachydacite                     406
# 11                        Dacite                       0
# 12  Andesite / Basaltic Andesite                    5657
# 13  Andesite / Basaltic Andesite                       0
# 14  Andesite / Basaltic Andesite                    4918
# 15  Andesite / Basaltic Andesite                       3
# 17  Andesite / Basaltic Andesite                    2062
# 18         Basalt / Picro-Basalt                     376
# 19  Andesite / Basaltic Andesite                     127
# 21         Basalt / Picro-Basalt                       0
# 22         Basalt / Picro-Basalt                       0
# 23         Basalt / Picro-Basalt                     156
# 24         Basalt / Picro-Basalt                     290
# 27  Andesite / Basaltic Andesite                       0
# 29                        Dacite                   91323
# 0   Andesite / Basaltic Andesite                    3597
#
#     population_within_10_km  population_within_30_km  \
# 0                      9594                   117805
# 2                     60730                  1042836
# 3                    127863                   218469
# 4                        70                     4019
# 5                      3936                   717078
# 8                         0                        0
# 10                    17272                   113131
# 11                        0                      103
# 12                    76781                   968381
# 13                        0                        0
# 14                   113874                   905254
# 15                        3                      615
# 17                     2062                     9756
# 18                     3864                   216708
# 19                      721                    55493
# 21                       24                      233
# 22                       64                       64
# 23                      925                    13459
# 24                      290                      388
# 27                        0                        0
# 29                   287487                  1126942
# 0                      9594                   117805
#
#     population_within_100_km dataset abbrev_evidence
# 0                    4071152    Tiny              ED
# 2                    7634778    Tiny              EO
# 3                    2253483    Tiny              ED
# 4                     393303    Tiny              ED
# 5                    5024654    Tiny              EO
# 8                          0    Tiny              EO
# 10                    119653    Tiny              EO
# 11                      5698    Tiny              ED
# 12                   4550176    Tiny              EO
# 13                         0    Tiny              ED
# 14                   2610033    Tiny              EO
# 15                     12484    Tiny              EO
# 17                    929538    Tiny              EO
# 18                   2521611    Tiny              EO
# 19                   3122037    Tiny              EO
# 21                      4361    Tiny              EO
# 22                      2887    Tiny              EO
# 23                    330411    Tiny              EO
# 24                     10756    Tiny              EO
# 27                         0    Tiny              ED
# 29                   6828403    Tiny              EO
# 0                    4071152    Tiny              ED

# %% [markdown]
# #### <font color="coral"> Not covered but still important </font>
# - `.dropna()` more info [here](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html)

# %% [markdown]
# #### <font color="coral"> Combining multiple dataframes </font>
#
# Finally, let's practice combining different dataframes together. It might be the case that a `.csv`'s data is stored over multiple files, or two `.csv` files contain related data and it would be convenient to merge them together.
#
# Different "split" scenarios require combining on different axes, which are specified as arguments to `pd.concat()`.

# %% [markdown]
# ##### 1. Columns of a DataFrame are split across 2 files:
#
# In this first example, extra data about a volcano's geologic composition is stored in a separate file, `rock_type_tiny.csv`.
#
# This data has the same number of rows as `filtered_volcano_tiny.csv`. As such, we will combine the DataFrames horizontally, using `axis=1`.

# %%
# read in both dataframes
volc = pd.read_csv("volcano_data/filtered_volcano_tiny.csv")
rocks = pd.read_csv("volcano_data/rock_type_tiny.csv")

print(volc.shape)
print(rocks.shape)

combined_horizontal = pd.concat([volc, rocks], axis=1)
print(combined_horizontal.shape)
combined_horizontal.head()
# Out:
# (30, 17)
# (30, 9)
# (30, 26)
#    volcano_number     volcano_name primary_volcano_type last_eruption_year  \
# 0          283001              Abu            Shield(s)              -6850
# 1          355096       Acamarachi        Stratovolcano            Unknown
# 2          342080       Acatenango    Stratovolcano(es)               1972
# 3          213004  Acigol-Nevsehir              Caldera              -2080
# 4          321040            Adams        Stratovolcano                950
#
#          country                          region  \
# 0          Japan         Japan, Taiwan, Marianas
# 1          Chile                   South America
# 2      Guatemala      México and Central America
# 3         Turkey  Mediterranean and Western Asia
# 4  United States          Canada and Western USA
#
#                                subregion  latitude  longitude  elevation  ...  \
# 0                                 Honshu    34.500    131.600        641  ...
# 1  Northern Chile, Bolivia and Argentina   -23.292    -67.618       6023  ...
# 2                              Guatemala    14.501    -90.876       3976  ...
# 3                                 Turkey    38.537     34.621       1683  ...
# 4                       USA (Washington)    46.206   -121.490       3742  ...
#
#   population_within_100_km                  major_rock_2  \
# 0                  4071152         Basalt / Picro-Basalt
# 1                     9092  Andesite / Basaltic Andesite
# 2                  7634778                        Dacite
# 3                  2253483                        Dacite
# 4                   393303         Basalt / Picro-Basalt
#
#             major_rock_3                  major_rock_4  major_rock_5  \
# 0                 Dacite
# 1
# 2
# 3  Basalt / Picro-Basalt  Andesite / Basaltic Andesite
# 4
#
#             minor_rock_1  minor_rock_2 minor_rock_3 minor_rock_4 minor_rock_5
# 0
# 1
# 2  Basalt / Picro-Basalt
# 3
# 4                 Dacite
#
# [5 rows x 26 columns]

# %% [markdown]
# ##### 2. Rows of a dataframe are split across multiple files.
#
# In this case, there are hundreds of more volcanoes within our dataset than the original 30 we've been examining. We can stack these DataFrames on top of one another, using `pd.concat(axis=0)`.

# %%
tiny = pd.read_csv("volcano_data/filtered_volcano_tiny.csv")
remaining = pd.read_csv("volcano_data/filtered_volcano.csv")

print(tiny.shape)
print(remaining.shape)

complete_dataset = pd.concat([tiny, remaining], axis=0)
print(complete_dataset.shape)
# Out:
# (30, 17)
# (928, 17)
# (958, 17)

# %% [markdown]
# ##### 3. Data is shared between two datasets, want to combine them.
#
# The `merge` function is used to combine multiple datasets that contain similar data. For this example, we will be using the `filtered_events_tiny.csv`, which contains volcanic events associated with each volcano. The two tables share both `volcano_name` and `volcano_id` columns to facilitate the merge.
#
# A merge is made by calling `.merge()` on one dataset. The dataset to the left of the `.merge()` call is the "left" DataFrame and the DataFrame within the `.merge()` call is the "right" DataFrame.
#
# To make things even more fun, there are 4 types of merge:
# 1. `left`, keep all values in the 'left' dataframe, remove 'right' values that don't match
# 2. `right` keep all values in the 'right' DataFrame, remove 'left' values that don't match
# 3. `outer` keep all values, akin to a set union operator
# 4. `inner` keep only values that appear in both datasets, akin to a set intersetion operator

# %%
# let's look at events and volcanos
volcanos = pd.read_csv("volcano_data/filtered_volcano.csv")
events = pd.read_csv("volcano_data/filtered_events.csv")

print(volcanos.shape)
print(events.shape)

print(volcanos.columns)
print(events.columns)

print(events.columns[events.columns.isin(volcanos.columns)])
# Out:
# (928, 17)
# (19204, 10)
# Index(['volcano_number', 'volcano_name', 'primary_volcano_type',
#        'last_eruption_year', 'country', 'region', 'subregion', 'latitude',
#        'longitude', 'elevation', 'tectonic_settings', 'evidence_category',
#        'major_rock_1', 'population_within_5_km', 'population_within_10_km',
#        'population_within_30_km', 'population_within_100_km'],
#       dtype='object')
# Index(['volcano_number', 'volcano_name', 'eruption_number',
#        'eruption_start_year', 'event_number', 'event_type', 'event_remarks',
#        'event_date_year', 'event_date_month', 'event_date_day'],
#       dtype='object')
# Index(['volcano_number', 'volcano_name'], dtype='object')

# %%
# left merge, keep all volcanoes, throw away unmatched events
combined_left = volcanos.merge(events, on="volcano_number", how="left")
combined_left.shape
# Out:
# (16558, 26)

# %%
# left merge, keep all volcanoes, throw away unmatched events
combined_right = volcanos.merge(events, on="volcano_number", how="right")
combined_right.shape
# Out:
# (19204, 26)

# %%
# left merge, keep all volcanoes, throw away unmatched events
combined_outer = volcanos.merge(events, on="volcano_number", how="outer")
combined_outer.shape
# Out:
# (19787, 26)

# %%
# left merge, keep all volcanoes, throw away unmatched events
combined_inner = volcanos.merge(events, on="volcano_number", how="inner")
combined_inner.shape
# Out:
# (15975, 26)

# %% [markdown]
# #### <font color="coral"> Saving your dataframe </font>
# - `.to_csv(filepath)` or `.to_excel(filepath)`
#
# Finally, after you've done your manipulations, you can save your DataFrame locally.
#
# To avoid headaches in the future, pass in the `index=False` argument.

# %%
volc_tiny.to_csv("modified_tiny_volc.csv", index=False)

# %% [markdown]
# #### <font color="coral"> Saving what you've done here <f>
